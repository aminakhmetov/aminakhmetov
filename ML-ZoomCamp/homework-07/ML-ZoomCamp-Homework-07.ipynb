# %% [markdown]
# # This is the homework for week 07

# %%
import bentoml

# %% [markdown]
# Question 1: what is a version of BentoML

# %% [raw]
# (ml-zoomcamp) Arthur@MacBook-Pro-2 wget-1.19.5 % bentoml --version
# bentoml, version 1.0.7

# %% [markdown]
# Question 2:

# %% [raw]
# (ml-zoomcamp) Arthur@MacBook-Pro-2 56umi2ss5se5vrft % ls -l
# total 416
# -rw-r--r--  1 Arthur  staff     716 Oct 23 18:08 custom_objects.pkl
# -rw-r--r--  1 Arthur  staff     366 Oct 23 18:08 model.yaml
# -rw-r--r--  1 Arthur  staff  201435 Oct 23 18:08 saved_model.ubj

# %% [markdown]
# Question 3

# %% [raw]
# class UserProfile(BaseModel):
#     name: str
#     age: int
#     country: str
#     rating: float

# %% [markdown]
# Question 4

# %% [raw]
# (ml-zoomcamp) Arthur@MacBook-Pro-2 models % bentoml models get mlzoomcamp_homework
# name: mlzoomcamp_homework
# version: qtzdz3slg6mwwdu5
# module: bentoml.sklearn
# labels: {}
# options: {}
# metadata: {}
# context:
#   framework_name: sklearn
#   framework_versions:
#     scikit-learn: 1.1.1
#   bentoml_version: 1.0.7
#   python_version: 3.9.12
# signatures:
#   predict:
#     batchable: false
# api_version: v1
# creation_time: '2022-10-13T20:42:14.411084+00:00'

# %% [markdown]
# Answer: 1.1.1

# %% [markdown]
# Question 5

# %% [markdown]
# Returns 1

# %% [markdown]
# Question 6

# %% [markdown]
# ![Q6.png](attachment:Q6.png)

# %% [markdown]
# Answer -- 2nd model is better for 1000 users and has better response
